# %% [markdown]
# <a href="https://colab.research.google.com/github/aflakhurridho/KKA-X-Semester-1-A-A-Ridho/blob/main/1_Fungsi_Print_AHMAD_AFLAKHUR_RIDHO_X_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAMA  : AHMAD AFLAKHUR RIDHO
#
# KELAS : X 1
#
# ABSEN : 01

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print("Ahmad Aflakhur Ridho")
# Out:
# Ahmad Aflakhur Ridho

# %% [markdown]
# #Menampilkan Nilai Fariabel

# %%
Nama_idola = "Xaviera Putri"

print(Nama_idola)
# Out:
# Xaviera Putri

# %%
usia = 24

print(usia)
# Out:
# 24

# %% [markdown]
# #Latihan Soal

# %%
nama_saudara = "irfan"

print(nama_saudara)
# Out:
# irfan

# %%
jumlah_saudara = 2

print(jumlah_saudara)
# Out:
# 2

# %% [markdown]
# #Menampilkan Nilai Variabel dan String

# %%
print("Nama idola saya adalah",Nama_idola,". Usianya adalah",usia,"tahun")
# Out:
# Nama idola saya adalah Xaviera Putri . Usianya adalah 24 tahun

# %%
print("Nama idola saya adalah "+Nama_idola+". Usianya adalah "+str(usia)+" tahun")
# Out:
# Nama idola saya adalah Xaviera Putri. Usianya adalah 24 tahun

# %%
print(f"Nama idola saya adalah {Nama_idola}. Usianya adalah {usia} tahun")
# Out:
# Nama idola saya adalah Xaviera Putri. Usianya adalah 24 tahun

# %% [markdown]
# #Escape String

# %%
print("Nama: A. Aflakhur Ridho")
print("Kelas: X.1")
print("No. Absen: 01")
# Out:
# Nama: A. Aflakhur Ridho
# Kelas: X.1
# No. Absen: 01

# %%
print("Nama: A. Aflakhur Ridho\nKelas: X.1\nNo. Absen: 01")print("Nama: A. Aflakhur Ridho\nKelas: X.1\nNo. Absen: 01")
# Out:
# Nama: A. Aflakhur Ridho
# Kelas: X.1
# No. Absen: 01

# %%
print("""Nama\t\t: A. Aflakhur Ridho
Kelas\t\t: X.1
No. Absen\t: 01""")
# Out:
# Nama		: A. Aflakhur Ridho
# Kelas		: X.1
# No. Absen	: 01

# %%
print("Hallo World I'm Ridho")
# Out:
# Hallo World I'm Ridho

# %%
print('Hallo World I\'m Ridho')
# Out:
# Hallo World I'm Ridho

# %%
print("Bu Shinta berkata, \"Tolong fokus ke TV sejenak.\"")
# Out:
# Bu Shinta berkata, "Tolong fokus ke TV sejenak."

# %%
print('Bu Shinta berkata, "Tolong fokus ke TV sejenak."')
# Out:
# Bu Shinta berkata, "Tolong fokus ke TV sejenak."

# %%
print("Silahkan simpan file tugas KKA di folder local disk D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Silahkan simpan file tugas KKA di folder local disk D:\MAN Demak\KKA\Tugas

# %%
print('Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.2 yang disimpan di file D:\\MAN Demak\\Jadwal Piket."\n')
print("Senin\tSelasa\tRabu\nJielo\tHasbi\tNaufal\nAzam\tA\'inun\tNurul")
# Out:
# Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.2 yang disimpan di file D:\MAN Demak\Jadwal Piket."
#
# Senin	Selasa	Rabu
# Jielo	Hasbi	Naufal
# Azam	A'inun	Nurul

# %% [markdown]
# #Parameter Fungsi print

# %%
nama_siswa_1 = "Dias"
nama_siswa_2 = "Disa"

print(nama_siswa_1, end=" ")
print(nama_siswa_2)
# Out:
# Dias Disa

# %%
print(nama_siswa_1, nama_siswa_2)
# Out:
# Dias Disa

# %%
print(nama_siswa_1, nama_siswa_2, sep="-")
# Out:
# Dias-Disa

# %%
nama_siswa_3 = "Kinan"
nama_siswa_4 = "Azka"
nama_siswa_5 = "Naufal"
nama_siswa_6 = "Ridho"
print(nama_siswa_6, nama_siswa_3, nama_siswa_5, nama_siswa_4, nama_siswa_4, sep="/")
# Out:
# Ridho/Kinan/Naufal/Azka/Azka

# %%
print(nama_siswa_4, end="*")
print(nama_siswa_4, end="*")
print(nama_siswa_5, end="*")
print(nama_siswa_3, end="*")
print(nama_siswa_6,)
# Out:
# Azka*Azka*Naufal*Kinan*Ridho
